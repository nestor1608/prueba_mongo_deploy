# %%
import pandas as pd
import pymongo

# %%
data_mongo = pymongo.MongoClient('mongodb+srv://brandon:brandon1@cluster0.tfvievv.mongodb.net/?retryWrites=true&w=majority')

# Seleccionar una base de datos existente o crear una nueva llamada 'test'.
db = data_mongo['test']

# %%
def mongo_data(collection):
    mongoColle= db[collection]
    data= list(mongoColle.find())
    df= pd.json_normalize(data,sep='_')
    df._id=df._id.astype(str)
    return df

# %%
setle_n= mongo_data('settlements')

# %%
setle_n
# Out:
#                         _id  \
# 0  643d68845d392b976ac0228a
# 1  643d68845d392b976ac02286
# 2  643d68845d392b976ac02289
# 3  643d68845d392b976ac02283
# 4  643d68845d392b976ac02284
# 5  643d68845d392b976ac02288
# 6  643d68845d392b976ac02285
# 7  643d68845d392b976ac0228b
# 8  643d68845d392b976ac02287
#
#                                         enabledUsers  \
# 0                         [6201245070900d002592d7ec]
# 1                         [6201245070900d002592d7ec]
# 2                         [6201245070900d002592d7ec]
# 3  [6201245070900d002592d7ec, 636c17ea2bd5b200305...
# 4                         [6201245070900d002592d7ec]
# 5  [6201245070900d002592d7ec, 63ecb2e2a9f1a400257...
# 6                         [6201245070900d002592d7ec]
# 7                         [6201245070900d002592d7ec]
# 8                         [6201245070900d002592d7ec]
#
#                                                plots  enabled  \
# 0                         [642b1d27cc00091984864f0d]    False
# 1  [63e6456b22ee080030ba8756, 6414cf9bb2505016885...    False
# 2                                                 []    False
# 3  [63b55f4b973f9f35c0c5b37d, 63b55f4b973f9f35c0c...     True
# 4  [63877cd7e1ed590030662d11, 63d116f852372700318...    False
# 5  [63eff7fbebcff60025f5d968, 63effaa9eb90f92734f...     True
# 6                         [63f8c5c6110f66003023ec90]    False
# 7                         [642c0e4a6490e600305e18eb]     True
# 8                         [63f8fd2a3c8b18002f20a41e]    False
#
#                                               limits  \
# 0                                                 []
# 1  [{'_id': 63e6454922ee080030ba8729, 'lat': -32....
# 2  [{'_id': 63ff75624c2d6d003084c118, 'lat': -26....
# 3  [{'_id': 63cedb56ea0de8476c39744d, 'lat': -32....
# 4  [{'_id': 63cedb6dea0de8476c39747b, 'lat': -33....
# 5  [{'_id': 63ecf27ba9f1a40025792ad0, 'lat': -34....
# 6  [{'_id': 63f01465e572c6002f4d73f2, 'lat': -32....
# 7  [{'_id': 642c0b596490e600305e181a, 'lat': -26....
# 8  [{'_id': 63efd78d65980f4378711b70, 'lat': -32....
#
#                                         centralPoint   hectares  \
# 0                [{'_id': 642b1d27cc00091984864f0b}]    79.9866
# 1  [{'_id': 63e6454922ee080030ba872d, 'lat': -32....     0.5700
# 2  [{'_id': 63ff75624c2d6d003084c11c, 'lat': -26....    61.5600
# 3  [{'_id': 63cedb56ea0de8476c397457, 'lat': -32....  5000.0000
# 4  [{'_id': 63cedb6dea0de8476c39747f, 'lat': -33....   100.0000
# 5  [{'_id': 63ecf27ba9f1a40025792ad4, 'lat': -34....     1.0900
# 6  [{'_id': 63f01465e572c6002f4d73f5, 'lat': -32....     0.2100
# 7  [{'_id': 642c0b596490e600305e181e, 'lat': -26....    11.3300
# 8  [{'_id': 63ecf27ba9f1a40025792ad4, 'lat': -34....     0.0200
#
#   registerNumber  headsCount                       name  \
# 0                        0.0               prueba macsa
# 1           None         NaN  establecimiento de prueba
# 2            NaN         NaN                     Prueba
# 3      XCSS12345        10.0                 La Florida
# 4       12311413       100.0                 Stock Test
# 5           None         NaN                      MACSA
# 6           None         NaN                     prueba
# 7           None         NaN                       Test
# 8           None         NaN               prueba macsa
#
#                 createdAt               updatedAt  __v  \
# 0 2023-04-03 18:38:31.434 2023-04-03 18:39:36.413    0
# 1 2023-02-10 13:23:21.915 2023-04-03 18:39:57.746    0
# 2 2023-03-01 15:55:14.078 2023-03-01 15:55:45.760    0
# 3 2022-02-17 15:48:47.058 2023-02-17 15:11:39.739    0
# 4 2022-11-30 15:55:03.627 2023-02-07 21:47:03.299    0
# 5 2023-02-15 14:55:55.972 2023-03-23 14:29:30.396    0
# 6 2023-02-10 13:09:16.013 2023-02-27 19:07:42.186    0
# 7 2023-04-04 11:34:49.097 2023-04-04 11:47:23.175    0
# 8 2023-02-17 19:37:49.367 2023-04-03 18:39:48.051    0
#
#                                       auravantApiKey
# 0                                                NaN
# 1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...
# 2  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...
# 3  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...
# 4  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...
# 5  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...
# 6  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...
# 7                                                NaN
# 8  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...

# %%
local = pymongo.MongoClient('localHost:27017')

# %%
db_local=local['test']

local_setle= db_local['settlements']

# %%
data= list(local_setle.find())
df= pd.json_normalize(data,sep='_')
df._id=df._id.astype(str)

# %%
df
# Out:
#                         _id  \
# 0  620e6e5e60543d0026a01f0e
# 1  63877cd7e1ed590030662d0a
# 2  63e641fc22ee080030ba838b
# 3  63e6454922ee080030ba8728
# 4  63efd78d65980f4378711b6f
# 5  63ecf27ba9f1a40025792acf
# 6  63ff75624c2d6d003084c117
# 7  642b1d27cc00091984864f0a
# 8  642c0b596490e600305e1819
#
#                                         enabledUsers  \
# 0  [6201245070900d002592d7ec, 636c17ea2bd5b200305...
# 1                         [6201245070900d002592d7ec]
# 2                         [6201245070900d002592d7ec]
# 3                         [6201245070900d002592d7ec]
# 4                         [6201245070900d002592d7ec]
# 5  [6201245070900d002592d7ec, 63ecb2e2a9f1a400257...
# 6                         [6201245070900d002592d7ec]
# 7                         [6201245070900d002592d7ec]
# 8                         [6201245070900d002592d7ec]
#
#                                                plots  \
# 0  [63b55f4b973f9f35c0c5b37d, 63b55f4b973f9f35c0c...
# 1  [63877cd7e1ed590030662d11, 63d116f852372700318...
# 2                         [63f8c5c6110f66003023ec90]
# 3  [63e6456b22ee080030ba8756, 6414cf9bb2505016885...
# 4                         [63f8fd2a3c8b18002f20a41e]
# 5  [63eff7fbebcff60025f5d968, 63effaa9eb90f92734f...
# 6                                                 []
# 7                         [642b1d27cc00091984864f0d]
# 8                         [642c0e4a6490e600305e18eb]
#
#                                               limits   hectares  \
# 0  [{'_id': 63cedb56ea0de8476c39744d, 'lat': -32....  5000.0000
# 1  [{'_id': 63cedb6dea0de8476c39747b, 'lat': -33....   100.0000
# 2  [{'_id': 63f01465e572c6002f4d73f2, 'lat': -32....     0.2100
# 3  [{'_id': 63e6454922ee080030ba8729, 'lat': -32....     0.5700
# 4  [{'_id': 63efd78d65980f4378711b70, 'lat': -32....     0.0200
# 5  [{'_id': 63ecf27ba9f1a40025792ad0, 'lat': -34....     1.0900
# 6  [{'_id': 63ff75624c2d6d003084c118, 'lat': -26....    61.5600
# 7                                                 []    79.9866
# 8  [{'_id': 642c0b596490e600305e181a, 'lat': -26....    11.3300
#
#   registerNumber  headsCount                       name  \
# 0      XCSS12345        10.0                 La Florida
# 1       12311413       100.0                 Stock Test
# 2           None         NaN                     prueba
# 3           None         NaN  establecimiento de prueba
# 4           None         NaN               prueba macsa
# 5           None         NaN                      MACSA
# 6            NaN         NaN                     Prueba
# 7                        0.0               prueba macsa
# 8           None         NaN                       Test
#
#                 createdAt               updatedAt  __v  \
# 0 2022-02-17 15:48:47.058 2023-02-17 15:11:39.739    0
# 1 2022-11-30 15:55:03.627 2023-02-07 21:47:03.299    0
# 2 2023-02-10 13:09:16.013 2023-02-27 19:07:42.186    0
# 3 2023-02-10 13:23:21.915 2023-04-03 18:39:57.746    0
# 4 2023-02-17 19:37:49.367 2023-04-03 18:39:48.051    0
# 5 2023-02-15 14:55:55.972 2023-03-23 14:29:30.396    0
# 6 2023-03-01 15:55:14.078 2023-03-01 15:55:45.760    0
# 7 2023-04-03 18:38:31.434 2023-04-03 18:39:36.413    0
# 8 2023-04-04 11:34:49.097 2023-04-04 11:47:23.175    0
#
#                                         centralPoint  \
# 0  [{'_id': 63cedb56ea0de8476c397457, 'lat': -32....
# 1  [{'_id': 63cedb6dea0de8476c39747f, 'lat': -33....
# 2  [{'_id': 63f01465e572c6002f4d73f5, 'lat': -32....
# 3  [{'_id': 63e6454922ee080030ba872d, 'lat': -32....
# 4  [{'_id': 63ecf27ba9f1a40025792ad4, 'lat': -34....
# 5  [{'_id': 63ecf27ba9f1a40025792ad4, 'lat': -34....
# 6  [{'_id': 63ff75624c2d6d003084c11c, 'lat': -26....
# 7                [{'_id': 642b1d27cc00091984864f0b}]
# 8  [{'_id': 642c0b596490e600305e181e, 'lat': -26....
#
#                                       auravantApiKey  enabled
# 0  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...     True
# 1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...    False
# 2  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...    False
# 3  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...    False
# 4  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...    False
# 5  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...     True
# 6  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzcmMiO...    False
# 7                                                NaN    False
# 8                                                NaN     True

# %%
cambio={'643d68845d392b976ac0228a':'642b1d27cc00091984864f0a',	
'643d68845d392b976ac02286':'63e6454922ee080030ba8728',	
'643d68845d392b976ac02289':'63ff75624c2d6d003084c117',	
'643d68845d392b976ac02283':'620e6e5e60543d0026a01f0e',	
'643d68845d392b976ac02284':'63877cd7e1ed590030662d0a',	
'643d68845d392b976ac02288':'63ecf27ba9f1a40025792acf',	
'643d68845d392b976ac02285':'63e641fc22ee080030ba838b',	
'643d68845d392b976ac0228b':'642c0b596490e600305e1819',	
'643d68845d392b976ac02287':'63efd78d65980f4378711b6f'}
